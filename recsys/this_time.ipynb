# %% [markdown]
# https://www.kaggle.com/code/ibtesama/getting-started-with-a-movie-recommendation-system

# %% [markdown]
# %pip install opendatasets

# %%
import opendatasets as od

# %% [markdown]
# username	"***"
# key	"****"
# Ensure kaggle.json is in the location ~/.kaggle/kaggle.json to use the API.

# %%
od.download("https://www.kaggle.com/datasets/rounakbanik/the-movies-dataset")
# Out:
# Skipping, found downloaded files in "./the-movies-dataset" (use force=True to force download)

# %%
import pandas as pd 
import numpy as np 

df_creds=pd.read_csv('/Users/alboard/source/kaggle/kaggle/recsys/the-movies-dataset/credits.csv', low_memory=False)
df_meta=pd.read_csv('/Users/alboard/source/kaggle/kaggle/recsys/the-movies-dataset/movies_metadata.csv', low_memory=False)

# %%
df_creds.head()
# Out:
#                                                 cast  \
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1  [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2  [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3  [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4  [{'cast_id': 1, 'character': 'George Banks', '...
#
#                                                 crew     id
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...    862
# 1  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...   8844
# 2  [{'credit_id': '52fe466a9251416c75077a89', 'de...  15602
# 3  [{'credit_id': '52fe44779251416c91011acb', 'de...  31357
# 4  [{'credit_id': '52fe44959251416c75039ed7', 'de...  11862

# %%
df_meta.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
# infer data types better than read csv did 
df_creds=df_creds.convert_dtypes()
df_creds.dtypes
# Out:
# cast    string
# crew    string
# id       Int64
# dtype: object

# %%
df_meta=df_meta.convert_dtypes()
df_meta.dtypes
# Out:
# adult                     string
# belongs_to_collection     string
# budget                    string
# genres                    string
# homepage                  string
# id                        string
# imdb_id                   string
# original_language         string
# original_title            string
# overview                  string
# popularity                string
# poster_path               string
# production_companies      string
# production_countries      string
# release_date              string
# revenue                    Int64
# runtime                    Int64
# spoken_languages          string
# status                    string
# tagline                   string
# title                     string
# video                    boolean
# vote_average             Float64
# vote_count                 Int64
# dtype: object

# %%
for col in ['id']:
    df_creds[col] = df_creds[col].astype('string')

# %%
# there are duplicate ids in the credits dataframe?
df_movies= df_meta.merge(df_creds,on='id')

# %%
df_movies.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                               <NA>  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                               <NA>  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
# could remove outliers here
m= df_movies['vote_count'].quantile(0.9)
print(m)
C= df_movies['vote_average'].mean()
print(C)
# Out:
# 160
# 5.618232129131438

# %% [markdown]
# df_popular_movies = df_movies.copy().loc[df_movies['vote_count'] >= m]
# df_popular_movies.shape

# %%
# We see that there are 481 movies which qualify to be in this list. Now, we need to calculate our metric for each qualified movie. To do this, we will define a function, weighted_rating() and define a new feature score, of which we'll calculate the value by applying this function to our DataFrame of qualified movies:

def weighted_rating(x, m=m, C=C):
    v = x['vote_count']
    R = x['vote_average']
    # Calculation based on the IMDB formula
    return (v/(v+m) * R) + (m/(m+v) * C)

# %%
# Define a new feature 'score' and calculate its value with `weighted_rating()`
df_movies['score'] = df_movies.apply(weighted_rating, axis=1)

# %%
#Sort movies based on score calculated above
df_movies = df_movies.sort_values('score', ascending=False)

#Print the top 15 movies
df_movies[['title', 'vote_count', 'vote_average', 'score']].head(10)
# Out:
#                              title  vote_count  vote_average     score
# 314       The Shawshank Redemption        8358           8.5   8.44587
# 837                  The Godfather        6024           8.5  8.425439
# 10345  Dilwale Dulhania Le Jayenge         661           9.1  8.421458
# 12525              The Dark Knight       12269           8.3  8.265477
# 2854                    Fight Club        9678           8.3  8.256385
# 292                   Pulp Fiction        8670           8.3  8.251406
# 522               Schindler's List        4436           8.3   8.20664
# 23742                     Whiplash        4376           8.3  8.205405
# 5501                 Spirited Away        3968           8.3  8.196056
# 2219             Life Is Beautiful        3643           8.3  8.187173

# %%
df_movies['overview'].head(5)
# Out:
# 314      Framed in the 1940s for the double murder of h...
# 837      Spanning the years 1945 to 1955, a chronicle o...
# 10345    Raj is a rich, carefree, happy-go-lucky second...
# 12525    Batman raises the stakes in his war on crime. ...
# 2854     A ticking-time-bomb insomniac and a slippery s...
# Name: overview, dtype: string

# %%
#Import TfIdfVectorizer from scikit-learn
from sklearn.feature_extraction.text import TfidfVectorizer

#Define a TF-IDF Vectorizer Object. Remove all english stop words such as 'the', 'a'
tfidf = TfidfVectorizer(stop_words='english')

#Replace NaN with an empty string
df_meta['overview'] = df_meta['overview'].fillna('')

#Construct the required TF-IDF matrix by fitting and transforming the data
tfidf_matrix = tfidf.fit_transform(df_meta['overview'])

#Output the shape of tfidf_matrix
tfidf_matrix.shape
# Out:
# (45466, 75827)

# %%
tfidf_matrix
# Out:
# <45466x75827 sparse matrix of type '<class 'numpy.float64'>'
# 	with 1210882 stored elements in Compressed Sparse Row format>

# %%
# Import linear_kernel
from sklearn.metrics.pairwise import linear_kernel

# Compute the cosine similarity matrix
cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)

# %%
#Construct a reverse map of indices and movie titles
indices = pd.Series(df_meta.index, index=df_meta['title']).drop_duplicates()

# %%
indices.head()
# Out:
# title
# Toy Story                      0
# Jumanji                        1
# Grumpier Old Men               2
# Waiting to Exhale              3
# Father of the Bride Part II    4
# dtype: int64

# %%
# Function that takes in movie title as input and outputs most similar movies
def get_recommendations(title, cosine_sim=cosine_sim):
    # Get the index of the movie that matches the title
    idx = indices[title]

    # Get the pairwsie similarity scores of all movies with that movie
    sim_scores = list(enumerate(cosine_sim[idx]))

    # Sort the movies based on the similarity scores
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)

    # Get the scores of the 10 most similar movies
    sim_scores = sim_scores[1:11]

    # Get the movie indices
    movie_indices = [i[0] for i in sim_scores]

    # Return the top 10 most similar movies
    return df_movies['title'].iloc[movie_indices]

# %%
get_recommendations('The Dark Knight Rises')
# Out:
# 21365                The Human Behavior Experiments
# 42246                                         Logan
# 24936                                   Babysitting
# 2575                           A Place at the Table
# 7199                               Good bye, Lenin!
# 6402                          Man's Favorite Sport?
# 15435    Casino Jack and the United States of Money
# 3022                             A Map of the World
# 27369                                  Station West
# 2309                          Young Sherlock Holmes
# Name: title, dtype: string

# %%
df_meta.columns
df_creds.columns
df_movies.head()
# Out:
#        adult                              belongs_to_collection     budget  \
# 314    False                                               <NA>   25000000
# 837    False  {'id': 230, 'name': 'The Godfather Collection'...    6000000
# 10345  False                                               <NA>   13200000
# 12525  False  {'id': 263, 'name': 'The Dark Knight Collectio...  185000000
# 2854   False                                               <NA>   63000000
#
#                                                   genres  \
# 314    [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
# 837    [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
# 10345  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 12525  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# 2854                       [{'id': 18, 'name': 'Drama'}]
#
#                                            homepage     id    imdb_id  \
# 314                                            <NA>    278  tt0111161
# ...

# %%
# Parse the stringified features into their corresponding python objects
from ast import literal_eval

features = ['cast', 'crew', 'genres']
for feature in features:
    df_movies[feature] = df_movies[feature].apply(literal_eval)

# %%
df_movies['crew'].head()
# Out:
# 314      [{'credit_id': '52fe4231c3a36847f800b127', 'de...
# 837      [{'credit_id': '52fe422bc3a36847f80093db', 'de...
# 10345    [{'credit_id': '57a3054a9251417c57000d7a', 'de...
# 12525    [{'credit_id': '55a0eb4a925141296b0010f8', 'de...
# 2854     [{'credit_id': '55731b8192514111610027d7', 'de...
# Name: crew, dtype: object

# %%
def get_director(x):
    for i in x:
        if i['job'] == 'Director':
            return i['name']
    return np.nan

# %%
def get_list(x):
    if isinstance(x, list):
        names = [i['name'] for i in x]
        #Check if more than 3 elements exist. If yes, return only first three. If no, return entire list.
        if len(names) > 3:
            names = names[:3]
        return names

    #Return empty list in case of missing/malformed data
    return []

# %%
# Define new director, cast, genres and keywords features that are in a suitable form.
df_movies['director'] = df_movies['crew'].apply(get_director)

# %%
df_movies['director'].head( )
# Out:
# 314            Frank Darabont
# 837      Francis Ford Coppola
# 10345           Aditya Chopra
# 12525       Christopher Nolan
# 2854            David Fincher
# Name: director, dtype: object

# %%
features = ['cast', 'crew', 'genres']
for feature in features:
    df_movies[feature] = df_movies[feature].apply(get_list)

# %%
def clean_data(x):
    if isinstance(x, list):
        return [str.lower(i.replace(" ", "")) for i in x]
    else:
        #Check if director exists. If not, return empty string
        if isinstance(x, str):
            return str.lower(x.replace(" ", ""))
        else:
            return ''

# %%
features = ['director', 'cast', 'crew', 'genres']

for feature in features:
    df_movies[feature] = df_movies[feature].apply(clean_data)

# %%
def create_soup(x):
    return  ' '.join(x['cast']) + ' ' + x['director'] + ' ' + ' '.join(x['genres'])
df_movies['soup'] = df_movies.apply(create_soup, axis=1)

# %%
df_movies[['soup', 'director', 'cast', 'crew', 'genres']].head( )
# Out:
#                                                     soup            director  \
# 314    timrobbins morganfreeman bobgunton frankdarabo...       frankdarabont
# 837    marlonbrando alpacino jamescaan francisfordcop...  francisfordcoppola
# 10345  shahrukhkhan kajol amrishpuri adityachopra com...        adityachopra
# 12525  christianbale michaelcaine heathledger christo...    christophernolan
# 2854   edwardnorton bradpitt meatloaf davidfincher drama        davidfincher
#
#                                              cast  \
# 314        [timrobbins, morganfreeman, bobgunton]
# 837           [marlonbrando, alpacino, jamescaan]
# 10345           [shahrukhkhan, kajol, amrishpuri]
# 12525  [christianbale, michaelcaine, heathledger]
# 2854           [edwardnorton, bradpitt, meatloaf]
#
#                                                     crew  \
# 314            [frankdarabont, nikimarvin, thomasnewman]
# 837    [francisfordcoppola, francisfordcoppola, grayf...
# ...

# %%
# Import CountVectorizer and create the count matrix
from sklearn.feature_extraction.text import CountVectorizer

count = CountVectorizer(stop_words='english')
count_matrix = count.fit_transform(df_movies['soup'])
# Compute the Cosine Similarity matrix based on the count_matrix
from sklearn.metrics.pairwise import cosine_similarity

cosine_sim2 = cosine_similarity(count_matrix, count_matrix)

# Reset index of our main DataFrame and construct reverse mapping as before
df_movies = df_movies.reset_index()
indices = pd.Series(df_movies.index, index=df_movies['title'])

# We can now reuse our get_recommendations() function by passing in the new cosine_sim2 matrix as your second argument.

# %%
get_recommendations('The Dark Knight Rises', cosine_sim2)
get_recommendations('The Godfather', cosine_sim2)
# Out:
# 10               The Godfather: Part II
# 670             The Godfather: Part III
# 33674                   The Rain People
# 60                       Apocalypse Now
# 1880                      The Outsiders
# 8607                        The Gambler
# 35889                  Gardens of Stone
# 36414    The Night of the Following Day
# 1889           And Then There Were None
# 21132            Manuscripts Don't Burn
# Name: title, dtype: string

# %%
# %pip install scikit-surprise
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# ...
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# WARNING: There was an error checking the latest version of pip.
# Note: you may need to restart the kernel to use updated packages.

# %%
# from surprise import Reader, Dataset, SVD, evaluate
from surprise import SVD, Reader
from surprise import Dataset
from surprise.model_selection import cross_validate
reader = Reader()
ratings = pd.read_csv('/Users/alboard/source/kaggle/kaggle/recsys/the-movies-dataset/ratings_small.csv')
ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1       31     2.5  1260759144
# 1       1     1029     3.0  1260759179
# 2       1     1061     3.0  1260759182
# 3       1     1129     2.0  1260759185
# 4       1     1172     4.0  1260759205

# %% [markdown]
# data = Dataset.load_from_df(ratings[['userId', 'movieId', 'rating']], reader)
# data.split(n_folds=5)

# %%
from surprise import SVD
from surprise import Dataset
from surprise import accuracy
from surprise.model_selection import KFold
from surprise.model_selection import GridSearchCV


# Load the movielens-100k dataset
data = Dataset.load_from_df(ratings[['userId', 'movieId', 'rating']], reader)

param_grid = {'n_epochs': [5, 10], 'lr_all': [0.002, 0.005],
              'reg_all': [0.4, 0.6]}
gs = GridSearchCV(SVD, param_grid, measures=['rmse', 'mae'], cv=3)

gs.fit(data)

# best RMSE score
print(gs.best_score['rmse'])

# combination of parameters that gave the best RMSE score
print(gs.best_params['rmse'])
# Out:
# 0.9144901951789665
# {'n_epochs': 10, 'lr_all': 0.005, 'reg_all': 0.4}

# %%
trainset = data.build_full_trainset()
svd = SVD()
svd.fit(trainset)

# %%
ratings[ratings['userId'] == 1]
# Out:
#     userId  movieId  rating   timestamp
# 0        1       31     2.5  1260759144
# 1        1     1029     3.0  1260759179
# 2        1     1061     3.0  1260759182
# 3        1     1129     2.0  1260759185
# 4        1     1172     4.0  1260759205
# 5        1     1263     2.0  1260759151
# 6        1     1287     2.0  1260759187
# 7        1     1293     2.0  1260759148
# 8        1     1339     3.5  1260759125
# 9        1     1343     2.0  1260759131
# 10       1     1371     2.5  1260759135
# 11       1     1405     1.0  1260759203
# 12       1     1953     4.0  1260759191
# 13       1     2105     4.0  1260759139
# 14       1     2150     3.0  1260759194
# 15       1     2193     2.0  1260759198
# 16       1     2294     2.0  1260759108
# 17       1     2455     2.5  1260759113
# 18       1     2968     1.0  1260759200
# 19       1     3671     3.0  1260759117

# %%
svd.predict(1,3671,2)
# Out:
# Prediction(uid=1, iid=3671, r_ui=2, est=2.977053171784346, details={'was_impossible': False})

# %%
def convert_int(x):
    try:
        return int(x)
    except:
        return np.nan

# %% [markdown]
# id_map = pd.read_csv('/Users/alboard/source/kaggle/kaggle/recsys/the-movies-dataset/links_small.csv')[['movieId', 'tmdbId']]
# # id_map['tmdbId'] = id_map['tmdbId'].apply(convert_int)
# id_map.columns = ['movieId', 'id']
# id_map = id_map.merge(df_movies, on='id')
# id_map.head()

# %%
id_map = pd.read_csv('/Users/alboard/source/kaggle/kaggle/recsys/the-movies-dataset/links.csv')
# id_map['tmdbId'] = id_map['tmdbId'].apply(convert_int)
id_map.sort_values(by='movieId').head()
id_map.dtypes 
id_map.loc[id_map['tmdbId'] == 10001]
df_movies['id']= df_movies['id'].apply(convert_int)
id_map['id'] = id_map['tmdbId'].apply(convert_int)
id_map['id'] = id_map['id'].apply(convert_int)
#id_map['id']=id_map['id'].astype('int64') 
id_map.head()
# Out:
#    movieId  imdbId   tmdbId       id
# 0        1  114709    862.0    862.0
# 1        2  113497   8844.0   8844.0
# 2        3  113228  15602.0  15602.0
# 3        4  114885  31357.0  31357.0
# 4        5  113041  11862.0  11862.0

# %%
df_movies=df_movies.convert_dtypes()
df_movies.dtypes
df_movies['id']= df_movies['id'].astype('int64') 
df_movies[['id', 'imdb_id', 'title']].sort_values('id').head()
df_movies.dtypes
# id_map = id_map.merge(df_movies[['title', 'id']], on='id')
id_map=id_map.convert_dtypes()
id_map.dtypes
df_movies.dtypes
# id_map = id_map.merge(df_movies[['title', 'id']], on='id')
df_movies[['id', 'imdb_id', 'title']].sort_values('id').head()
# Out:
#       id    imdb_id                title
# 5290   2  tt0094675                Ariel
# 6055   3  tt0092149  Shadows in Paradise
# 2480   5  tt0113101           Four Rooms
# 6218   6  tt0107286       Judgment Night
# 24    11  tt0076759            Star Wars

# %%
id_map.head()
id_map.dtypes
id_map['id']= id_map['id'].astype('float64')

# %%
id_map.sort_values(by='id').head()
id_map=id_map.convert_dtypes()
id_map.dtypes
# Out:
# movieId    Int64
# imdbId     Int64
# tmdbId     Int64
# id         Int64
# dtype: object

# %%
df_movies['id']= df_movies['id'].astype('float64')
df_movies=df_movies.convert_dtypes()
df_movies.dtypes
# Out:
# index                      Int64
# adult                     string
# belongs_to_collection     string
# budget                    string
# genres                    object
# homepage                  string
# id                         Int64
# imdb_id                   string
# original_language         string
# original_title            string
# overview                  string
# popularity                string
# poster_path               string
# production_companies      string
# production_countries      string
# release_date              string
# revenue                    Int64
# runtime                    Int64
# spoken_languages          string
# status                    string
# tagline                   string
# title                     string
# video                    boolean
# vote_average             Float64
# vote_count                 Int64
# cast                      object
# crew                      object
# score                     object
# ...

# %%
df_movies[['id', 'imdb_id', 'title']].sort_values('id').head()
# Out:
#       id    imdb_id                title
# 5290   2  tt0094675                Ariel
# 6055   3  tt0092149  Shadows in Paradise
# 2480   5  tt0113101           Four Rooms
# 6218   6  tt0107286       Judgment Night
# 24    11  tt0076759            Star Wars

# %%
id_map = id_map.merge(df_movies[['title', 'id']], on='id').set_index('title')

# %%
id_map.shape
# Out:
# (45668, 4)

# %%
indices_map = id_map.set_index('id')

# %%
df_movies.columns
# Out:
# Index(['index', 'adult', 'belongs_to_collection', 'budget', 'genres',
#        'homepage', 'id', 'imdb_id', 'original_language', 'original_title',
#        'overview', 'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count', 'cast', 'crew', 'score', 'director',
#        'soup'],
#       dtype='object')

# %%
def hybrid(userId, title):
    idx = indices[title]
    tmdbId = id_map.loc[title]['id']
    #print(idx)
    movie_id = id_map.loc[title]['movieId']
    
    sim_scores = list(enumerate(cosine_sim[int(idx)]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:26]
    movie_indices = [i[0] for i in sim_scores]
    
    # movies = df_movies.iloc[movie_indices][['title', 'vote_count', 'vote_average', 'year', 'id']]
    movies = df_movies.iloc[movie_indices][['title', 'id']]
    movies['est'] = movies['id'].apply(lambda x: svd.predict(userId, indices_map.loc[x]['movieId']).est)
    movies = movies.sort_values('est', ascending=False)
    return movies.head(10)

# %%
hybrid(500, 'Avatar')
# Out:
#                                              title      id       est
# 4193                                    Jesus Camp    1776  3.578258
# 6475                      The Man from Snowy River   24266  3.353123
# 500                                   Lost Highway     638  3.148435
# 32194                               Silent Madness   42710  2.959204
# 29261  Perry Mason: The Case of the Reckless Romeo   95400  2.959204
# 34082                                     The Deal   10274  2.959204
# 26778                               Survival Quest  100110  2.959204
# 26681                                        Sonja  114931  2.959204
# 34252                               As You Like It   19103  2.959204
# 36702                               Mom's Day Away  279332  2.959204

# %%
hybrid(1, 'Avatar')
# Out:
#                                              title      id       est
# 4193                                    Jesus Camp    1776  2.988978
# 6475                      The Man from Snowy River   24266  2.767064
# 41946                                   Mixed Nuts   24070  2.729665
# 500                                   Lost Highway     638  2.706443
# 29261  Perry Mason: The Case of the Reckless Romeo   95400  2.676711
# 34082                                     The Deal   10274  2.676711
# 26778                               Survival Quest  100110  2.676711
# 26681                                        Sonja  114931  2.676711
# 34252                               As You Like It   19103  2.676711
# 36702                               Mom's Day Away  279332  2.676711
